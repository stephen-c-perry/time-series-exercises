# %%
import wrangle as w 
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import prepare as p
from datetime import timedelta, datetime

# %matplotlib inline

# %% [markdown]
# Using your store items data:
#
# 1) Convert date column to datetime format.
# 2) Plot the distribution of sale_amount and item_price.
# 3) Set the index to be the datetime variable.
# 4) Add a 'month' and 'day of week' column to your dataframe.
# 5) Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.
# 6) Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:
#
# 1) Convert date column to datetime format.
# 2) Plot the distribution of each of your variables.
# 3) Set the index to be the datetime variable.
# 4) Add a month and a year column to your dataframe.
# 5) Fill any missing values.
# 6) Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
df = w.acquire_store()

# %% [markdown]
# 1) Convert date column to datetime format.

# %%
df.sale_date = pd.to_datetime(df.sale_date)

# %% [markdown]
# 2) Plot the distribution of sale_amount and item_price.

# %%
sns.relplot(x= df.item_price, y= df.sale_amount)

# %%
sns.relplot(x=df.index, y=df.sale_amount)

# %%
sns.relplot(x=df.index, y=df.item_price)

# %% [markdown]
# 3) Set the index to be the datetime variable.

# %%
df = df.set_index('sale_date')

# %% [markdown]
# 4) Add a 'month' and 'day of week' column to your dataframe.

# %%
df['month'] = df.index.month

# %%
df['day_of_week'] = df.index.day_name()

# %%
df.head()
# Out:
#             sale_amount item_brand                       item_name  \
# sale_date
# 2013-01-01           13   Riceland  Riceland American Jazmine Rice
# 2013-01-02           11   Riceland  Riceland American Jazmine Rice
# 2013-01-03           14   Riceland  Riceland American Jazmine Rice
# 2013-01-04           13   Riceland  Riceland American Jazmine Rice
# 2013-01-05           10   Riceland  Riceland American Jazmine Rice
#
#             item_price           store_address  store_zipcode  month  \
# sale_date
# 2013-01-01        0.84  12125 Alamo Ranch Pkwy          78253      1
# 2013-01-02        0.84  12125 Alamo Ranch Pkwy          78253      1
# 2013-01-03        0.84  12125 Alamo Ranch Pkwy          78253      1
# 2013-01-04        0.84  12125 Alamo Ranch Pkwy          78253      1
# 2013-01-05        0.84  12125 Alamo Ranch Pkwy          78253      1
#
#            day_of_week
# sale_date
# 2013-01-01     Tuesday
# 2013-01-02   Wednesday
# 2013-01-03    Thursday
# 2013-01-04      Friday
# 2013-01-05    Saturday

# %% [markdown]
# 5) Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
df['sales_total'] = df['sale_amount'] * df['item_price']

# %% [markdown]
# 6) Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
def prep_store():

    df = w.acquire_store()
    df.sale_date = pd.to_datetime(df.sale_date)
    sns.relplot(x= df.item_price, y= df.sale_amount)
    sns.relplot(x=df.index, y=df.sale_amount)
    df = df.set_index('sale_date')
    df['month'] = df.index.month
    df['day_of_week'] = df.index.day_name()
    df['sales_total'] = df['sale_amount'] * df['item_price']

    return df

# %% [markdown]
# - - -

# %% [markdown]
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:
#
# 1) Convert date column to datetime format.

# %%
OPS_df = pd.read_csv('opsd_germany_daily.csv')

# %% [markdown]
# 2) Plot the distribution of each of your variables.

# %%
variables = ['Consumption','Wind', 'Solar', 'Wind+Solar']
OPS_df[variables].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 3) Set the index to be the datetime variable.

# %%
OPS_df = OPS_df.set_index('Date').sort_index()

# %%
OPS_df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  month
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN      2
# 2006-01-02     1380.521   NaN    NaN         NaN      2
# 2006-01-03     1442.533   NaN    NaN         NaN      2
# 2006-01-04     1457.217   NaN    NaN         NaN      2
# 2006-01-05     1477.131   NaN    NaN         NaN      2

# %% [markdown]
# 4) Add a month and a year column to your dataframe.

# %%
OPS_df['month'] = OPS_df.index.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/yogibexar/codeup-data-science/time-series-exercises/prepare.ipynb Cell 30 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yogibexar/codeup-data-science/time-series-exercises/prepare.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> OPS_df['month'] = OPS_df.index.month()
#
# AttributeError: 'Index' object has no attribute 'month'

# %% [markdown]
# 5) Fill any missing values.

# %% [markdown]
# 6) Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
